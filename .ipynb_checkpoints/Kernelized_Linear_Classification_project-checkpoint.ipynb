# %% [markdown]
# # Kernelized Linear Classification Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from math import exp

# %%
dataset_pd = pd.read_csv('your_dataset.csv')
dataset = dataset_pd.to_numpy()
dataset_pd
# Out:
#             x1        x2          x3        x4        x5        x6        x7  \
# 0     1.205492  5.823226   98.837539 -1.075852  0.999205  0.911543  3.623558
# 1     1.391530  3.611581   98.857197 -5.020318  0.677165  0.999492  3.413112
# 2     1.692571 -0.887019  100.901276 -0.595548  0.177550 -0.915495  4.320264
# 3     4.289320  1.416843  100.784735 -2.897154 -0.066972 -0.786173  2.093003
# 4     0.542420 -1.010095  100.015580 -3.070705  0.088324 -0.242669  0.767942
# ...        ...       ...         ...       ...       ...       ...       ...
# 9995  0.481134 -0.572225   99.274788 -0.868047 -0.663229  0.572447  5.163238
# 9996  0.047373  0.990198  100.444834 -0.707179  0.912113 -0.510397  1.128577
# 9997  1.741933  0.036304  100.524071 -0.113742 -0.761337 -0.728295 -1.334732
# 9998  2.574986  0.041442   98.983735 -1.937883  0.983004  0.798133  5.847342
# 9999  0.123523 -1.518412   99.159300 -2.024888  0.785601  0.745629 -0.457173
#
#             x8        x9        x10  y
# 0    -1.720267 -0.346191 -54.708330 -1
# 1     4.253865  2.041603 -54.317291  1
# 2     0.907834  3.126815 -56.397484 -1
# 3     1.336237  2.183829 -56.197728  1
# 4    -0.284683 -2.104145 -55.794045  1
# ...        ...       ...        ... ..
# 9995  1.765743  0.720265 -54.952233 -1
# 9996  0.116130 -2.559018 -56.008656 -1
# 9997 -1.312760 -0.442573 -56.170876 -1
# 9998  0.904038 -1.695064 -54.820699  1
# 9999  0.408771 -2.163518 -54.806434  1
#
# [10000 rows x 11 columns]

# %%
dataset_pd.hist(bins=60, figsize=(20, 15))
plt.show()

# %%
# Seperating data point and labels
X = np.array([x[:-1] for x in dataset])
y = np.array([int(x[-1]) for x in dataset])

print(f'X: {X.shape[0]} samples and {X.shape[1]} features, y: {y.shape[0]} labels')
# Out:
# X: 10000 samples and 10 features, y: 10000 labels

# %%
def data_split(X, y, train_size=0.75):
    x_train = X[:int(train_size * len(X))]
    x_test = X[int(train_size * len(X)):]
    y_train = y[:int(train_size * len(y))]
    y_test = y[int(train_size * len(y)):]

    return x_train, x_test, y_train, y_test

# split data set to train and test samples
x_train, x_test, y_train, y_test = data_split(X, y, train_size=0.75)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((7500, 10), (2500, 10), (7500,), (2500,))

# %% [markdown]
# ## Scaling Dataset

# %%
def z_score(set_train, set_test):
    mean = np.mean(set_train, axis=0)
    std = np.std(set_train, axis=0)
    z_train = (set_train - mean) / std
    z_test = (set_test - mean) / std # scale test set with mean and standard deviation from training set
    return z_train, z_test

def min_max(set_train, set_test):
    minimum = np.min(set_train, axis=0)
    maximum = np.max(set_train, axis=0)
    return (set_train - minimum) / (maximum - minimum), (set_test - minimum) / (maximum - minimum)

# %% [markdown]
# ## Accuracy

# %%
def accuracy(y_test, y_pred):
    T = 0
    for i in range(len(y_test)):
        if y_test[i] == y_pred[i]:
            T += 1

    return f'{100 * T / len(y_test)} %'

# %% [markdown]
# ## Learning Algorithms

# %% [markdown]
# ### Perceptron Algorithm

# %%
class Perceptron():
    def __init__(self, learn_rate=0.01, n_iters=1000):
        self.lr = learn_rate
        self.n_iters = n_iters

    def fit(self, X, y):
        n_samples, n_features = X.shape
        # Initialize weights and bias
        self.w = np.zeros(n_features)
        self.b = 0
        # Transform labels from -1/1 to 0/1
        # _y = np.where(y > 0, 1, 0) CHANGED
        _y = np.where(y > 0, 1, -1)

        for _ in range(self.n_iters):
            # for i, x in enumerate(X):
            #     y_predict = self.step(np.dot(x, self.w) + self.b)
            #     # Update Rule
            #     self.w += self.lr * (_y[i] - y_predict) * x
            #     self.b += self.lr * (_y[i] - y_predict)

            for i, x in enumerate(X):
                y_predict = self.step(np.dot(x, self.w) + self.b)
                if y_predict != _y[i]:
                    self.w += self.lr * _y[i] * x
                    self.b += self.lr * _y[i]

        # DELETE
        return self.w, self.b


    def step(self, x):
        # return np.where(x > 0, 1, 0) CHANGED
        return np.where(x > 0, 1, -1)

    def predict(self, x):
        y_predict = self.step(np.dot(x, self.w) + self.b)
        # Transfrom 0/1 prediction to -1/1
        return np.where(y_predict > 0, 1, -1)

# %% [markdown]
# * Test with and without scaling, different learning rate and without, different iteratoins

# %%
# Initialize model
p = Perceptron(learn_rate=0.1, n_iters=1000)

# Scale data
x_train_scaled, x_test_scaled = z_score(x_train, x_test)

# Train the model
p.fit(x_train_scaled, y_train)

# predict 
y_pred = p.predict(x_test_scaled)

# Accuracy
accuracy(y_test, y_pred)
# Out:
# '59.96 %'

# %%
# predict 
y_pred = p.predict(x_train_scaled)

# Accuracy
accuracy(y_train, y_pred) # with training set
# Out:
# '60.4 %'

# %% [markdown]
# #### Perceptron Testing

# %%
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
np.random.seed(654)

# %%
XX, yy = make_blobs(n_samples=1000, centers=2)
yy = np.where(yy > 0, 1, -1)
fig = plt.figure(figsize=(8,6))
plt.scatter(XX[:,0], XX[:,1], c=yy)
plt.title("Dataset")
plt.xlabel("First feature")
plt.ylabel("Second feature")
plt.show()

# %%
y_true = yy[:, np.newaxis]

X_train, X_test, y_train, y_test = data_split(XX, y_true)
print(f'Shape X_train: {X_train.shape}')
print(f'Shape y_train: {y_train.shape})')
print(f'Shape X_test: {X_test.shape}')
print(f'Shape y_test: {y_test.shape}')
# Out:
# Shape X_train: (750, 2)
# Shape y_train: (750, 1))
# Shape X_test: (250, 2)
# Shape y_test: (250, 1)

# %%
p_test = Perceptron(n_iters=100)

x_train_scaled, x_test_scaled = z_score(X_train, X_test)

# Train the model
w, b = p_test.fit(X_train, y_train)

# predict 
y_pred = p_test.predict(X_test)

# Accuracy
accuracy(y_test, y_pred)
# Out:
# 1.0

# %%
def plot_hyperplane(X, y, weights, bias):
    """
    Plots the dataset and the estimated decision hyperplane
    """
    slope = - weights[0]/weights[1]
    intercept = - bias/weights[1]
    x_hyperplane = np.linspace(-10,14,10)
    y_hyperplane = slope * x_hyperplane + intercept
    fig = plt.figure(figsize=(8,6))
    plt.scatter(X[:,0], X[:,1], c=y)
    plt.plot(x_hyperplane, y_hyperplane, '-')
    plt.title("Dataset and fitted decision hyperplane")
    plt.xlabel("First feature")
    plt.ylabel("Second feature")
    plt.xlim(-5, 10)
    plt.ylim(-13, 5)
    plt.show()

plot_hyperplane(XX, yy, w, b)

# %% [markdown]
# ### Support Vector Machines (SVMs) using the Pegasos Algorithm

# %%
class PegasosSVM():
    def __init__(self, lambda_param=0.01, n_iters=1000):
        self.lp = lambda_param
        self.n_iters = n_iters

    def fit(self, X, y):
        n_samples, n_features = X.shape

        # Initialize weights and bias
        self.w = np.zeros(n_features) 
        self.b = 0

        for t in range(1, self.n_iters + 1):
            for _ in range(n_samples):
                i = random.randint(0, n_samples - 1) 
                eta = 1 / (self.lp * t)
                condition = y[i] * (np.dot(X[i], self.w) + self.b)
                if condition < 1:
                    self.w = ((1 - (1/t)) * self.w) + (eta * y[i] * X[i])
                    self.b += eta * y[i]
                else:
                    self.w = ((1 - (1/t)) * self.w)

    def predict(self, x):
        output = np.dot(x, self.w) + self.b
        return np.sign(output)

# %%
# Initialize model
svm = PegasosSVM(n_iters=1500)

# Train model
svm.fit(x_train_scaled, y_train)

# Predict
y_pred = svm.predict(x_test_scaled)

# Accuracy
accuracy(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[333], line 2
#       1 # Initialize model
# ----> 2 svm = PegasosSVM(n_iters=1500)
#       4 # Train model
#       5 svm.fit(x_train_scaled, y_train)
#
# NameError: name 'PegasosSVM' is not defined

# %% [markdown]
# #### test new pegasos

# %%
class SVM_Pegasos():
    def __init__(self, lambda_param=0.01, n_iters=1000):
        self.lambda_param = lambda_param
        self.n_iters = n_iters

    def fit(self, X, y):
        n_samples, n_features = X.shape

        self.w = np.zeros(n_features)

        for t in range(1, self.n_iters + 1):
            eta = 1 / (self.lambda_param * t)
            i = random.randint(0, n_samples - 1)
            if y[i] * X[i] @ self.w < 1:
                self.w = (1 - 1/t) * self.w + (eta * y[i] * X[i])
            else:
                self.w = (1 - 1/t) * self.w

    def predict(self, x):
        return np.sign(x @ self.w)

# %%
model = SVM_Pegasos(n_iters=50000)
model.fit(x_train_scaled, y_train)
y_pred = model.predict(x_test_scaled)

accuracy(y_test, y_pred)
# Out:
# '71.28 %'

# %%
# predict 
y_pred = model.predict(x_train_scaled)

# Accuracy
accuracy(y_train, y_pred) # with training set
# Out:
# '72.64 %'

# %% [markdown]
# ### Regularized logistic classification

# %%
class LogisticPegasos():
    def __init__(self,lambda_param=0.01, n_iters=1000):
        self.lp = lambda_param
        self.n_iters = n_iters

    def fit(self, X, y):
        n_samples, n_features = X.shape

        # Initialize weights and bias
        self.w = np.zeros(n_features)
        self.b = 0
        
        # Transform labels from -1/1 to 0/1
        # _y = np.where(y > 0, 1, 0)

        for t in range(1, self.n_iters + 1):
            # loss
            l = 0
            for _ in range(n_samples):
                i = random.randint(0, n_samples - 1) 
                eta = 1 / (self.lp * t)
                
                # loss
                l += np.log2(1 + np.exp(-y[i] * self.predict(X[i])))
                
                gradient_w = -self.sigmoid(y[i]*np.dot(self.w, X[i])) * (y[i] * X[i])
                gradient_b = -self.sigmoid(y[i]*np.dot(self.w, X[i])) * y[i]
                self.w = (1 - 1/t) * self.w + eta * gradient_w
                self.b += eta * gradient_b

            print(l / n_samples)

    def sigmoid(self, z):
        return 1 / (1 + np.exp(z))
    
    def predict(self, x):
        output = self.sigmoid(np.dot(x, self.w) + self.b)
        return np.where(output >= 0.5, 1, -1)

# %%
# Initialize model
LP = LogisticPegasos(n_iters=500)

# Scale data
x_train_scaled, x_test_scaled = z_score(x_train, x_test)

# Train model
LP.fit(x_train_scaled, y_train)

# Predict
y_pred = LP.predict(x_test_scaled)

# Accuracy
accuracy(y_test, y_pred)

# %% [markdown]
# #### Test new logistic pegasos

# %%
class PegasosLogistic():
    def __init__(self, lambda_param=0.01, n_iters=1000):
        self.lambda_param = lambda_param
        self.n_iters = n_iters

    def fit(self, X, y):
        n_samples, n_features = X.shape

        self.w = np.zeros(n_features)
        # loss_before = sum((-y[j] * np.log(self.sigmoid(X[j] @ self.w))) - (1 - y[j]) * (np.log(1 - self.sigmoid(X[j] @ self.w))) for j in range(n_samples))
        for t in range(1, self.n_iters+1):
            eta = 1 / (self.lambda_param * t)
            i = random.randint(0, n_samples-1)

            z = self.sigmoid(X[i] @ self.w)
            if y[i] != z:
                self.w = (1 - 1/t) * self.w - (eta * (z - y[i]) * X[i])

        # loss_after = [(-y[j] * np.log(self.sigmoid(X[j] @ self.w))) - (1 - y[j]) * (np.log(1 - self.sigmoid(X[j] @ self.w))) for j in range(n_samples)]

        # return loss_before, loss_after

    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def predict(self, x):
        z = self.sigmoid(x @ self.w)
        return np.where(z >= 0.5, 1, -1)

# %%
model = PegasosLogistic(n_iters=50000)

model.fit(x_train_scaled, y_train)

y_pred = model.predict(x_test_scaled)

accuracy(y_test, y_pred)
# Out:
# '71.36 %'

# %% [markdown]
# ## Polynomial Feature Expansion of Algorithms

# %%
def polynomial_features_d2(X):
    n_samples, n_features = X.shape
    poly_features = []
   
    poly_features.append(X)

    for i in range(n_features):
        poly_features.append(X[:, i:i+1] ** 2)

    for i in range(n_features):
        for j in range(i+1, n_features):
            poly_features.append(X[:, i:i+1] * X[:, j:j+1])
        
    return np.hstack(poly_features)

# %%
poly_X = polynomial_features_d2(X)
poly_X.shape
# Out:
# (10000, 65)

# %%
x_train, x_test, y_train, y_test = data_split(poly_X, y, train_size=0.75)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((7500, 65), (2500, 65), (7500,), (2500,))

# %% [markdown]
# ### Perceptron (Polynomial Features)

# %%
p_poly = Perceptron(learn_rate=0.1, n_iters=1000)

# Scale data
x_train_scaled, x_test_scaled = z_score(x_train, x_test)

# Train the model
p_poly.fit(x_train_scaled, y_train)

# predict 
y_pred = p_poly.predict(x_test_scaled)

# Accuracy
accuracy(y_test, y_pred)
# Out:
# '90.96 %'

# %% [markdown]
# ### SVM Pegasos (Polynomial Features)

# %%
# Initialize model
svm_poly = PegasosSVM(n_iters=1500)

# Train model
svm_poly.fit(x_train_scaled, y_train)

# Predict
y_pred = svm_poly.predict(x_test_scaled)

# Accuracy
accuracy(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[368], line 2
#       1 # Initialize model
# ----> 2 svm_poly = PegasosSVM(n_iters=1500)
#       4 # Train model
#       5 svm_poly.fit(x_train_scaled, y_train)
#
# NameError: name 'PegasosSVM' is not defined
